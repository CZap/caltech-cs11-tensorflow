# %% [markdown]
# # Lab 3: Mapping with Fully-Connected Networks
# Blocks of dense layers are really good at memorizing patterns.
# This week we'll step outside the traditional "prediction" regime of machine learning and use a fully-connected network (FCN) to represent a 2-D scene in its weight by interpolating between known points.
#
# Throughout, you should be impressed by two (related) properties of dense neural nets:
#  - They have high enough capacity to entirely memorize complex patterns
#  - They are sufficiently nonlinear to build these patterns up from simple inputs (like (x, y) coordinates in this case)

# %%
# %matplotlib inline

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import datetime

# %% [markdown]
# # Pointcloud mapping
#
# ![full scene](./images/full_scene.png)
#
# ### The problem
# Imagine there is a square (2-D) room with four walls and several square and circular objects in it.
# We put laser distance sensors around the room, which shoot rays that continue until they hit an object or a wall and report the distance, with limited angular and radial resolution.
# We want to use this limited data to produce a full 2-D reconstruction of the scene, filling in points the sensors haven't observed with likely values (in essence, interpolating).
#
# ### The data
# We know that every ray that there's an object at the point each ray hit, and we also know that there's no object between the camera and the contact point.
# The data is provided as (x, y) pairs, where some points correspond to places we know are on object boundaries (shown in green above) and points we know are not inside objects (shown in red above).
#
# These points come in two data files: `data/positives.txt` for points on the edge of objects, and `data/negatives.txt` for points outside of objects.
# To generate these files, run `make_data.py`.
#
# (Check out the code if you want to see how the points are generated, but don't change anything!)
#
# ### The model
# We want to store a full description of the scene in the weights of a neural network.
# To do this, we'll train a FCN to classify (x, y) points by whether or not they are the edge of a wall or object.
# Then, we can draw the scene by sampling (x, y) pairs and drawing the model's output.
# So, the network has "memorized" where the objects and walls are, and what their shapes are.

# %% [markdown]
# # Section 1: Load the data
# Load the data using `np.loadtxt()` (default arguments should work), then convert it to a usable format with a feature array and label array, which is 1 if a point is the edge of an object and 0 if it is not.
#
# Functions to look at:
#  - `np.loadtxt`
#  - `np.concatenate`

# %%
edge_pts = np.loadtxt('./data/positives.txt')
n_edge_pts = np.loadtxt('./data/negatives.txt')
#add labels
edge_pts = np.column_stack((np.ones((np.shape(edge_pts)[0], 1)), edge_pts))
n_edge_pts = np.column_stack((np.zeros((np.shape(n_edge_pts)[0], 1)), n_edge_pts))
#concatenate the two arrays
data_pts = np.concatenate((edge_pts, n_edge_pts))
#separate the data array into features and labels
data_labels = data_pts[:, 0]
data_features = data_pts[:, [1, 2]]

# %% [markdown]
# # Section 2: Build a data pipeline
# Set up a `tf.data.Dataset` and a `tf.summary.SummaryWriter`.
# This time, there's no test set, just a single dataset. You may want to use the `repeat` method on the dataset for the number of desired epochs. If so, call it after caching so as not to store redundant data.

# %%
n_train = data_features.shape[0]
n_features = data_features.shape[1]
n_classes = 2
n_epochs = 50
dataset_train =  tf.data.Dataset.from_tensor_slices((data_features, data_labels)).shuffle(500).batch(32).cache()
log_dir = "logs_lab3\\fit\\" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
train_writer = tf.summary.create_file_writer(log_dir + '/train')

# %% [markdown]
# # Section 3: Build a model graph
# The model is a simple fully-connected neural network with four hidden layers, each with 64 units, and an output layer that performs binary classification with sigmoid activation.
# Recall that the input is just a pair (x, y).
#
# Functions to look at throughout:
#  - `tf.cast`
#  - `tf.expand_dims`
#  - `tf.squeeze`
#  - arithmetic operations

# %% [markdown]
# ### 3.1: Class to make dense layers
# It's tedious (and bad design) to explicitly write out every variable, matrix multiplication, etc.
# Instead, it's common to define classes that create one of a structure you expect to repeat in your model.
#
# Write a `tf.Module` class called `Dense`, which has its signature and scopes defined as a stub below.
# When called, it should add variables and operations to the graph which implement a single dense layer.
#
# If `do_activation` is True, it should apply ReLU activation to the computed values.
# To do this, you can use `tf.nn.relu`.

# %%
class Dense(tf.Module):
    '''
    Creates a dense layer module.
    
    Parameters
    ----------
    dim_input: int
        Number of features in the input representation.
    dim_output: int
        Number of features in the output representation.
        Equivalently, number of units in this layer.
    do_activation: bool
        Whether or not to apply ReLU activation.
    postfix: string
        Postfix on name scopes in this layer.
        Used to simplify visualizations.
    name: string
        Name of layer.
        
    Returns
    -------
    A tensor representing the activations of this layer.
    '''
    def __init__(self, dim_input, dim_output, do_activation=True, postfix='', name=None):
        super().__init__(name=name)
        with tf.name_scope('dense' + postfix):
            self.kernel = tf.Variable(tf.initializers.he_uniform()(shape = (dim_input, dim_output,), dtype = tf.float64), \
                                   name = 'weights')
            self.bias = tf.Variable(tf.initializers.he_uniform()(shape = (dim_output,), dtype = tf.float64), name = 'bias')
            self.activation = do_activation
  
    def __call__(self, x):
        x = tf.cast(x, tf.float64)
        if len(tf.shape(x) == 1):
            x = tf.expand_dims(x, axis = 0)
        weights_product = tf.matmul(x, self.kernel)
        activation = tf.add(weights_product, tf.expand_dims(self.bias, axis = 0))
        if self.activation == True:
            activation = tf.nn.relu(activation)
        #print(tf.shape(activation), tf.shape(weights_product), tf.shape(self.kernel))
        return tf.squeeze(activation)

# %% [markdown]
# ### 3.2: Class to make neural network
# Use the `Dense` class to make four dense layers contained as fields in a `tf.Module` class called `FeedForward`.
# Each should have 64 units, the correct input dimensions, and a distinct (and meaningful) postfix.

# %% [markdown]
# #### 3.2.1: Compute logit
# Use the `Dense` class to make a final dense layer with `dim_output=1` to compute the final logit. You'll want to put this in a method called `logits` which should take in `self` and an input.

# %% [markdown]
# #### 3.2.2: Compute class probability for output
# Use `tf.sigmoid` to compute the probability that the input coordinate is a boundary point.
# We will not use this for the loss, just for the output. You'll want to put this in the `__call__` method.

# %% [markdown]
# #### 3.2.3: Trace function
# Decorate the `__call__` method with `@tf.function` in order to run a model trace for TensorBoard. I have defined this method for you here, but will not in the future.

# %%
class FeedForward(tf.Module):
    def __init__(self, name=None):
        super().__init__(name=name)
        self.layer1 = Dense(2, 64, postfix = 'l1')
        self.layer2 = Dense(64, 64, postfix = 'l2')
        self.layer3 = Dense(64, 64, postfix = 'l3')
        self.layer4 = Dense(64, 64, postfix = 'l4')
        self.end_layer = Dense(64, 1, postfix ='final')
    def logits(self, x):
        return self.end_layer((self.layer4(self.layer3(self.layer2(self.layer1(x))))))
    
    
    def __call__(self, x):
        #output = tf.sigmoid((self.layer4(self.layer3(self.layer2(self.layer1(x))))))
        output = tf.sigmoid(self.logits(x))
        return(output)

@tf.function
def trace_function(model, x):
    model(x)

# %% [markdown]
# ### 3.3: Compute weighted cross-entropy loss
# There are about 33 times as many non-boundary coordinates as there are boundary coordinates.
# To prevent the network from just learning to predict that every coordinate is not a boundary, we should weight the loss function to consider boundary pixels more heavily.
#
# To do this, use `tf.nn.weighted_cross_entropy_with_logits()` on the logits computed before, plus the input label, and a positive weight of 20.
# Then, produce the mean loss for the batch with `tf.reduce_mean`. Put this in a `_loss` method.

# %%
def _loss(labels, logits):
    cross_entropy_loss = tf.nn.weighted_cross_entropy_with_logits(labels, logits, pos_weight = 0)
    return tf.reduce_mean(cross_entropy_loss)

# %% [markdown]
# ### 3.4: Optimizer and gradients
# Make an optimizer (I used `tf.optimizers.SGD` with `learning_rate=2e-3` and `momentum=0.9`).
# Then write a train method (taking in a model, input, output, and step), that represents one step of training, where you explicitly compute the gradients in a variable called `gradients` (so we can plot them below) and make an operation that applies those gradients to the graph.
#
# Note: don't use `optimizer.minimize`, which will result in computing the gradients twice since we already have them from `GradientTape.gradient`. Add a summary scalar to plot loss in TensorBoard.

# %% [markdown]
# #### 3.4.1: Plot variables and gradients
# You don't need to do this for every model, but it's illustrative to do at least once. I've written the code for this below, with a pattern borrowed from http://matpalm.com/blog/viz_gradient_norms/. Put this code snippet under the same `with` block where you add your loss summary scalar.
#
# ```
# for gradient, variable in zip(gradients, model.trainable_variables):
#     if variable.name and gradient is not None:
#         tf.summary.histogram('gradients/' + variable.name, tf.norm(gradient), step=i)
#         tf.summary.histogram('variables/' + variable.name, tf.norm(variable), step=i)
# ```

# %%
optimizer = tf.optimizers.SGD(learning_rate=2e-3, momentum=0.9)

def train(model, x, y, i):
    with tf.GradientTape() as g:
        cross_entropy_loss = lambda: _loss(y, model.logits(x)) #lambda fn to get loss per batch
        gradients = g.gradient(cross_entropy_loss(), model.trainable_variables)
        with train_writer.as_default():
            gradients_and_vars = zip(gradients, model.trainable_variables)
            for gradient, variable in gradients_and_vars:
                if variable.name and gradient is not None:
                    tf.summary.histogram('gradients/' + variable.name, tf.norm(gradient), step=i)
                    tf.summary.histogram('variables/' + variable.name, tf.norm(variable), step=i)
                else:
                    if variable.name is None:
                        print('null var')
                    if gradient is None:
                        print('null gradient')
            tf.summary.scalar('cross-entropy loss', cross_entropy_loss(), step=i)
        optimizer.apply_gradients(gradients_and_vars)

# %% [markdown]
# # Section 4: train the model
# Same as last time, except there's no test set.
# You don't need to distinguish between epochs and steps here, but do run a full trace on the first batch to get the model graph in TensorBoard.
#
# I used 50 epochs, and got a final cross-entropy loss of about 0.4.
# You might not need to use this many epochs to get reasonable results, but more will get crisper results.
#
# This might take a while on CPUs, so if it's taking too long, think about:
#  - Using Google Colaboratory
#  - Increasing your batch size
#  - Reducing the frequency with which you run summary ops
#
# Watching plots, histograms, etc in TensorBoard as the model trains can be fun.

# %%
model = FeedForward()
train_batch = 0

for i in range(n_epochs):
    for x, y in dataset_train:
        if train_batch == 0:
            tf.summary.trace_on(graph=True, profiler=True) #initializing tensorboard graph
            trace_function(model, x) #running trace method once
            with train_writer.as_default():
                tf.summary.trace_export(name='first training batch', step=0, profiler_outdir=log_dir)
        train(model, x, y, train_batch) #calling train iteration
        train_batch += 1
#checkpoint for saving the model    
checkpoint = tf.train.Checkpoint(model = model)
checkpoint.write('./checkpoints_lab3/model')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-114-2e62a72c427b> in <module>
#       9             with train_writer.as_default():
#      10                 tf.summary.trace_export(name='first training batch', step=0, profiler_outdir=log_dir)
# ---> 11         train(model, x, y, train_batch) #calling train iteration
#      12         train_batch += 1
#      13 #checkpoint for saving the model
#
# <ipython-input-113-1fc8521e8548> in train(model, x, y, i)
#      10                 if variable.name and gradient is not None:
#      11                     tf.summary.histogram('gradients/' + variable.name, tf.norm(gradient), step=i)
# ---> 12                     tf.summary.histogram('variables/' + variable.name, tf.norm(variable), step=i)
#      13                 else:
#      14                     if variable.name is None:
#
# ~\anaconda3\envs\tf\lib\site-packages\tensorboard\plugins\histogram\summary_v2.py in histogram(name, data, step, buckets, description)
#     105             histogram_summary, data, buckets, summary_metadata, step
#     106         )
# --> 107     return histogram_summary(data, buckets, summary_metadata, step)
#     108
#     109
#
# ~\anaconda3\envs\tf\lib\site-packages\tensorboard\plugins\histogram\summary_v2.py in histogram_summary(data, buckets, histogram_metadata, step)
#      92                 tensor=lazy_tensor,
#      93                 step=step,
# ---> 94                 metadata=summary_metadata,
#      95             )
#      96
#
# ~\anaconda3\envs\tf\lib\site-packages\tensorflow_core\python\ops\summary_ops_v2.py in write(tag, tensor, step, metadata, name)
#     666
#     667     op = smart_cond.smart_cond(
# --> 668         _should_record_summaries_v2(), record, _nothing, name="summary_cond")
#     669     if not context.executing_eagerly():
#     670       ops.add_to_collection(ops.GraphKeys._SUMMARY_COLLECTION, op)  # pylint: disable=protected-access
#
# ~\anaconda3\envs\tf\lib\site-packages\tensorflow_core\python\framework\smart_cond.py in smart_cond(pred, true_fn, false_fn, name)
#      52   if pred_value is not None:
#      53     if pred_value:
# ---> 54       return true_fn()
#      55     else:
#      56       return false_fn()
#
# ~\anaconda3\envs\tf\lib\site-packages\tensorflow_core\python\ops\summary_ops_v2.py in record()
#     653       # Note the identity to move the tensor to the CPU.
#     654       with ops.device("cpu:0"):
# --> 655         summary_tensor = tensor() if callable(tensor) else array_ops.identity(
#     656             tensor)
#     657         write_summary_op = gen_summary_ops.write_summary(
#
# ~\anaconda3\envs\tf\lib\site-packages\tensorboard\util\lazy_tensor_creator.py in __call__(self)
#      64                 elif self._tensor is None:
#      65                     self._tensor = _CALL_IN_PROGRESS_SENTINEL
# ---> 66                     self._tensor = self._tensor_callable()
#      67         return self._tensor
#      68
#
# ~\anaconda3\envs\tf\lib\site-packages\tensorboard\plugins\histogram\summary_v2.py in lazy_tensor()
#      86             @lazy_tensor_creator.LazyTensorCreator
#      87             def lazy_tensor():
# ---> 88                 return _buckets(data, buckets)
#      89
#      90             return tf.summary.write(
#
# ~\anaconda3\envs\tf\lib\site-packages\tensorboard\plugins\histogram\summary_v2.py in _buckets(data, bucket_count)
#     126         data = tf.reshape(data, shape=[-1])  # flatten
#     127         data = tf.cast(data, tf.float64)
# --> 128         is_empty = tf.equal(tf.size(input=data), 0)
#     129
#     130         def when_empty():
#
# ~\anaconda3\envs\tf\lib\site-packages\tensorflow_core\python\util\dispatch.py in wrapper(*args, **kwargs)
#     178     """Call target, and fall back on dispatchers if there is a TypeError."""
#     179     try:
# --> 180       return target(*args, **kwargs)
#     181     except (TypeError, ValueError):
#     182       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~\anaconda3\envs\tf\lib\site-packages\tensorflow_core\python\ops\math_ops.py in equal(x, y, name)
#    1303     `tf.errors.InvalidArgumentError`: If shapes of arguments are incompatible
#    1304   """
# -> 1305   return gen_math_ops.equal(x, y, name=name)
#    1306
#    1307
#
# ~\anaconda3\envs\tf\lib\site-packages\tensorflow_core\python\ops\gen_math_ops.py in equal(x, y, incompatible_shape_error, name)
#    3220         _ctx._context_handle, tld.device_name, "Equal", name,
#    3221         tld.op_callbacks, x, y, "incompatible_shape_error",
# -> 3222         incompatible_shape_error)
#    3223       return _result
#    3224     except _core._FallbackException:
#
# KeyboardInterrupt:

# %% [markdown]
# # Section 5: Plot the model
# Let's see what the network learned.
# Generate 100 x values and 100 y values, each in the range (-1, 1).
# Then compute the value of `probability` (the sigmoid output of your model) using every coordinate in that grid (every pairwise combination of x and y values), and plot a "map" of those probabilities using `plt.scatter()` (check out the `c` argument).

# %%
test_points = tf.convert_to_tensor(np.random.uniform(np.nextafter(-1.0, 1.0), 1.0, (5000, 2)))
results_list = []
for j in range(tf.shape(test_points)[0]):
    results_list.append(model(test_points[j]))
results = tf.convert_to_tensor(results_list)
scatter = plt.scatter(test_points[:, 0], test_points[:, 1], results, cmap = 'hsv')
plt.show
#print(results)
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Section 6: TensorBoard plots
# This time, we have some more interesting TensorBoard plots than last time.
# Run TensorBoard, and look at:
#  - The model graph in Graphs
#  - The loss over time in Scalars
#  - The weights, biases, and gradients over time in Distributions and Histograms
#
# The loss should decrease over time, and eventually stabilize (with some noise).
#
# The gradients for weights and biases may not go to zero, and your weights and biases may not look like they're converging.
# This is because of "bias drift" where multiple possible settings of weights and biases have the same loss value.
# To fix this, we could add a term to the loss which penalizes the model slightly based on the magnitude of the bias terms.

# %% [markdown]
# # Section 7: Again, but in Keras
# Make a Keras Sequential model which is equivalent to the one we've trained in TensorFlow.
# Train it on the same dataset, and again plot its output in the same way.
#
# Hints:
#  - This won't take nearly as long as the previous sections
#  - You don't need to use `keras.utils.to_categorical` since this is binary classification.
#  - The appropriate loss function is 'binary_crossentropy'
#  - To implement the same loss weighting, use `class_weight={0: 1.0, 1:20.0}` in `model.fit()`
#  - You can get the outputs of the model over the entire grid at once with `model.predict()`

# %% [markdown]
# ### 7.1: Build a model
# Use `keras.models.Sequential` to build the same FCN as before.

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation

model2 = Sequential()

model2.add( Dense(64, input_shape=(2,)) )
model2.add(Activation('relu'))
model2.add(Dense(64, activation='relu'))
model2.add(Dense(64, activation='relu'))
model2.add(Dense(64, activation='relu'))
model2.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ### 7.2: Define an optimizer and compile the model

# %%
from keras.optimizers import SGD

optimizer = SGD(lr=2e-3, momentum=0.9)

model2.compile(optimizer=optimizer,
              loss='binary_crossentropy',
              metrics=['binary_accuracy',
                       'binary_crossentropy'])

# %% [markdown]
# ### 7.3: Fit the model

# %%
model2.fit(data_features, data_labels,
          epochs=100, batch_size=32, class_weight={0: 1.0, 1:20.0})
# Out:
# Epoch 1/100
# 28556/28556 [==============================] - 1s 34us/step - loss: 1.0220 - binary_accuracy: 0.9603 - binary_crossentropy: 0.5086
# Epoch 2/100
# 28556/28556 [==============================] - 1s 32us/step - loss: 0.9673 - binary_accuracy: 0.8888 - binary_crossentropy: 0.4708
# Epoch 3/100
# 28556/28556 [==============================] - 1s 31us/step - loss: 0.9351 - binary_accuracy: 0.8252 - binary_crossentropy: 0.4551
# Epoch 4/100
# 28556/28556 [==============================] - 1s 31us/step - loss: 0.9087 - binary_accuracy: 0.8238 - binary_crossentropy: 0.4483
# Epoch 5/100
# 28556/28556 [==============================] - 1s 32us/step - loss: 0.8807 - binary_accuracy: 0.8142 - binary_crossentropy: 0.4340
# Epoch 6/100
# 28556/28556 [==============================] - 1s 34us/step - loss: 0.8488 - binary_accuracy: 0.8135 - binary_crossentropy: 0.4228
# Epoch 7/100
# 28556/28556 [==============================] - 1s 32us/step - loss: 0.8188 - binary_accuracy: 0.8271 - binary_crossentropy: 0.4128
# Epoch 8/100
# 28556/28556 [==============================] - 1s 31us/step - loss: 0.7899 - binary_accuracy: 0.8275 - binary_crossentropy: 0.3982
# Epoch 9/100
# 28556/28556 [==============================] - 1s 33us/step - loss: 0.7458 - binary_accuracy: 0.8181 - binary_crossentropy: 0.3850
# Epoch 10/100
# 28556/28556 [==============================] - 1s 33us/step - loss: 0.6877 - binary_accuracy: 0.8245 - binary_crossentropy: 0.3602
# Epoch 11/100
# 28556/28556 [==============================] - 1s 43us/step - loss: 0.7079 - binary_accuracy: 0.8147 - binary_crossentropy: 0.3726
# Epoch 12/100
# 28556/28556 [==============================] - 1s 43us/step - loss: 0.6449 - binary_accuracy: 0.8268 - binary_crossentropy: 0.3429
# Epoch 13/100
# 28556/28556 [==============================] - 1s 42us/step - loss: 0.6275 - binary_accuracy: 0.8277 - binary_crossentropy: 0.3361
# Epoch 14/100
# 28556/28556 [==============================] - 1s 39us/step - loss: 0.5953 - binary_accuracy: 0.8331 - binary_crossentropy: 0.3196
# Epoch 15/100
# 28556/28556 [==============================] - 1s 44us/step - loss: 0.5889 - binary_accuracy: 0.8296 - binary_crossentropy: 0.3230
# Epoch 16/100
# 28556/28556 [==============================] - 1s 38us/step - loss: 0.5884 - binary_accuracy: 0.8370 - binary_crossentropy: 0.3249
# Epoch 17/100
# 28556/28556 [==============================] - 1s 31us/step - loss: 0.5857 - binary_accuracy: 0.8304 - binary_crossentropy: 0.3210
# Epoch 18/100
# 28556/28556 [==============================] - 1s 30us/step - loss: 0.5620 - binary_accuracy: 0.8380 - binary_crossentropy: 0.3077
# Epoch 19/100
# 28556/28556 [==============================] - 1s 30us/step - loss: 0.5555 - binary_accuracy: 0.8371 - binary_crossentropy: 0.3118
# Epoch 20/100
# 28556/28556 [==============================] - 1s 33us/step - loss: 0.5261 - binary_accuracy: 0.8415 - binary_crossentropy: 0.2945
# Epoch 21/100
# 28556/28556 [==============================] - 1s 32us/step - loss: 0.5361 - binary_accuracy: 0.8404 - binary_crossentropy: 0.3010
# Epoch 22/100
# 28556/28556 [==============================] - 1s 39us/step - loss: 0.5143 - binary_accuracy: 0.8484 - binary_crossentropy: 0.2898
# Epoch 23/100
# 28556/28556 [==============================] - 1s 36us/step - loss: 0.5102 - binary_accuracy: 0.8468 - binary_crossentropy: 0.2906
# Epoch 24/100
# 28556/28556 [==============================] - 1s 36us/step - loss: 0.5067 - binary_accuracy: 0.8488 - binary_crossentropy: 0.2838
# Epoch 25/100
# 28556/28556 [==============================] - 1s 32us/step - loss: 0.4918 - binary_accuracy: 0.8560 - binary_crossentropy: 0.2762: 0s - loss: 0.4922 - binary_accuracy: 0.8560 - binary_crossentropy: 0.276
# Epoch 26/100
# 28556/28556 [==============================] - 1s 39us/step - loss: 0.4944 - binary_accuracy: 0.8497 - binary_crossentropy: 0.2839
# Epoch 27/100
# 28556/28556 [==============================] - 1s 43us/step - loss: 0.4834 - binary_accuracy: 0.8504 - binary_crossentropy: 0.2787
# Epoch 28/100
# 28556/28556 [==============================] - 1s 37us/step - loss: 0.4696 - binary_accuracy: 0.8619 - binary_crossentropy: 0.2676
# Epoch 29/100
# 28556/28556 [==============================] - 1s 38us/step - loss: 0.4449 - binary_accuracy: 0.8622 - binary_crossentropy: 0.2561
# Epoch 30/100
# 28556/28556 [==============================] - 1s 38us/step - loss: 0.4481 - binary_accuracy: 0.8669 - binary_crossentropy: 0.2543
# Epoch 31/100
# 28556/28556 [==============================] - 1s 38us/step - loss: 0.4585 - binary_accuracy: 0.8650 - binary_crossentropy: 0.2613
# Epoch 32/100
# 28556/28556 [==============================] - 1s 37us/step - loss: 0.4704 - binary_accuracy: 0.8601 - binary_crossentropy: 0.2706
# Epoch 33/100
# 28556/28556 [==============================] - 1s 36us/step - loss: 0.4529 - binary_accuracy: 0.8665 - binary_crossentropy: 0.2582
# Epoch 34/100
# 28556/28556 [==============================] - 1s 39us/step - loss: 0.4333 - binary_accuracy: 0.8683 - binary_crossentropy: 0.2585
# Epoch 35/100
# 28556/28556 [==============================] - 1s 40us/step - loss: 0.4469 - binary_accuracy: 0.8688 - binary_crossentropy: 0.2567
# Epoch 36/100
# 28556/28556 [==============================] - 1s 35us/step - loss: 0.4407 - binary_accuracy: 0.8681 - binary_crossentropy: 0.2548
# Epoch 37/100
# 28556/28556 [==============================] - 1s 34us/step - loss: 0.4094 - binary_accuracy: 0.8769 - binary_crossentropy: 0.2396
# Epoch 38/100
# 28556/28556 [==============================] - 1s 33us/step - loss: 0.4210 - binary_accuracy: 0.8756 - binary_crossentropy: 0.2445
# Epoch 39/100
# 28556/28556 [==============================] - 1s 36us/step - loss: 0.4386 - binary_accuracy: 0.8706 - binary_crossentropy: 0.2531
# Epoch 40/100
# 28556/28556 [==============================] - 1s 41us/step - loss: 0.4053 - binary_accuracy: 0.8796 - binary_crossentropy: 0.2390
# Epoch 41/100
# 28556/28556 [==============================] - 1s 45us/step - loss: 0.4099 - binary_accuracy: 0.8815 - binary_crossentropy: 0.2377
# Epoch 42/100
# 28556/28556 [==============================] - 1s 45us/step - loss: 0.3880 - binary_accuracy: 0.8843 - binary_crossentropy: 0.2311
# Epoch 43/100
# 28556/28556 [==============================] - 1s 41us/step - loss: 0.4132 - binary_accuracy: 0.8802 - binary_crossentropy: 0.2382
# Epoch 44/100
# 28556/28556 [==============================] - 1s 41us/step - loss: 0.4045 - binary_accuracy: 0.8817 - binary_crossentropy: 0.2359
# Epoch 45/100
# 28556/28556 [==============================] - 1s 31us/step - loss: 0.4249 - binary_accuracy: 0.8807 - binary_crossentropy: 0.2435
# Epoch 46/100
# 28556/28556 [==============================] - 1s 32us/step - loss: 0.3820 - binary_accuracy: 0.8869 - binary_crossentropy: 0.2258
# Epoch 47/100
# 28556/28556 [==============================] - 1s 31us/step - loss: 0.3954 - binary_accuracy: 0.8853 - binary_crossentropy: 0.2343
# Epoch 48/100
# 28556/28556 [==============================] - 1s 31us/step - loss: 0.3676 - binary_accuracy: 0.8944 - binary_crossentropy: 0.2147
# Epoch 49/100
# 28556/28556 [==============================] - 1s 35us/step - loss: 0.3660 - binary_accuracy: 0.8936 - binary_crossentropy: 0.2160
# Epoch 50/100
# 28556/28556 [==============================] - 1s 34us/step - loss: 0.3864 - binary_accuracy: 0.8893 - binary_crossentropy: 0.2306
# Epoch 51/100
# 28556/28556 [==============================] - 1s 40us/step - loss: 0.3839 - binary_accuracy: 0.8871 - binary_crossentropy: 0.2283
# Epoch 52/100
# 28556/28556 [==============================] - 1s 46us/step - loss: 0.3873 - binary_accuracy: 0.8876 - binary_crossentropy: 0.2288
# Epoch 53/100
# 28556/28556 [==============================] - 2s 61us/step - loss: 0.3597 - binary_accuracy: 0.8948 - binary_crossentropy: 0.2152
# Epoch 54/100
# 28556/28556 [==============================] - 1s 52us/step - loss: 0.3843 - binary_accuracy: 0.8895 - binary_crossentropy: 0.2309
# Epoch 55/100
# 28556/28556 [==============================] - 2s 56us/step - loss: 0.3767 - binary_accuracy: 0.8884 - binary_crossentropy: 0.2261
# Epoch 56/100
# 28556/28556 [==============================] - 1s 51us/step - loss: 0.3867 - binary_accuracy: 0.8913 - binary_crossentropy: 0.2240
# Epoch 57/100
# 28556/28556 [==============================] - 2s 58us/step - loss: 0.3961 - binary_accuracy: 0.8913 - binary_crossentropy: 0.2256
# Epoch 58/100
# 28556/28556 [==============================] - 2s 61us/step - loss: 0.3323 - binary_accuracy: 0.9052 - binary_crossentropy: 0.2034
# Epoch 59/100
# 28556/28556 [==============================] - 2s 54us/step - loss: 0.3611 - binary_accuracy: 0.8951 - binary_crossentropy: 0.2198
# Epoch 60/100
# 28556/28556 [==============================] - 1s 52us/step - loss: 0.3491 - binary_accuracy: 0.9004 - binary_crossentropy: 0.2100
# Epoch 61/100
# 28556/28556 [==============================] - 1s 48us/step - loss: 0.3416 - binary_accuracy: 0.9015 - binary_crossentropy: 0.2089
# Epoch 62/100
# 28556/28556 [==============================] - 1s 42us/step - loss: 0.3621 - binary_accuracy: 0.8959 - binary_crossentropy: 0.2188
# Epoch 63/100
# 28556/28556 [==============================] - 1s 47us/step - loss: 0.3262 - binary_accuracy: 0.9057 - binary_crossentropy: 0.1986
# Epoch 64/100
# 28556/28556 [==============================] - 1s 40us/step - loss: 0.3686 - binary_accuracy: 0.8951 - binary_crossentropy: 0.2179
# Epoch 65/100
# 28556/28556 [==============================] - 1s 38us/step - loss: 0.3347 - binary_accuracy: 0.9053 - binary_crossentropy: 0.2044
# Epoch 66/100
# 28556/28556 [==============================] - 1s 48us/step - loss: 0.3302 - binary_accuracy: 0.9047 - binary_crossentropy: 0.2020
# Epoch 67/100
# 28556/28556 [==============================] - 2s 65us/step - loss: 0.3296 - binary_accuracy: 0.9050 - binary_crossentropy: 0.1968
# Epoch 68/100
# 28556/28556 [==============================] - 1s 39us/step - loss: 0.3476 - binary_accuracy: 0.8996 - binary_crossentropy: 0.2088
# Epoch 69/100
# 28556/28556 [==============================] - 1s 40us/step - loss: 0.3402 - binary_accuracy: 0.9024 - binary_crossentropy: 0.2066
# Epoch 70/100
# 28556/28556 [==============================] - 1s 37us/step - loss: 0.3251 - binary_accuracy: 0.9053 - binary_crossentropy: 0.1991
# Epoch 71/100
# 28556/28556 [==============================] - 1s 38us/step - loss: 0.3140 - binary_accuracy: 0.9084 - binary_crossentropy: 0.1932
# Epoch 72/100
# 28556/28556 [==============================] - 1s 42us/step - loss: 0.3365 - binary_accuracy: 0.9033 - binary_crossentropy: 0.2023
# Epoch 73/100
# 28556/28556 [==============================] - 1s 35us/step - loss: 0.3820 - binary_accuracy: 0.9003 - binary_crossentropy: 0.2182
# Epoch 74/100
# 28556/28556 [==============================] - 1s 34us/step - loss: 0.3144 - binary_accuracy: 0.9096 - binary_crossentropy: 0.1924
# Epoch 75/100
# 28556/28556 [==============================] - 1s 40us/step - loss: 0.3124 - binary_accuracy: 0.9105 - binary_crossentropy: 0.1910
# Epoch 76/100
# 28556/28556 [==============================] - 1s 43us/step - loss: 0.3134 - binary_accuracy: 0.9130 - binary_crossentropy: 0.1935
# Epoch 77/100
# 28556/28556 [==============================] - 1s 44us/step - loss: 0.3123 - binary_accuracy: 0.9129 - binary_crossentropy: 0.1900
# Epoch 78/100
# 28556/28556 [==============================] - 1s 38us/step - loss: 0.3115 - binary_accuracy: 0.9123 - binary_crossentropy: 0.1917
# Epoch 79/100
# 28556/28556 [==============================] - 1s 36us/step - loss: 0.3172 - binary_accuracy: 0.9117 - binary_crossentropy: 0.1877
# Epoch 80/100
# 28556/28556 [==============================] - 1s 44us/step - loss: 0.3155 - binary_accuracy: 0.9112 - binary_crossentropy: 0.1900
# Epoch 81/100
# 28556/28556 [==============================] - 1s 44us/step - loss: 0.3434 - binary_accuracy: 0.9070 - binary_crossentropy: 0.2033
# Epoch 82/100
# 28556/28556 [==============================] - 1s 41us/step - loss: 0.3039 - binary_accuracy: 0.9123 - binary_crossentropy: 0.1887
# Epoch 83/100
# 28556/28556 [==============================] - 1s 43us/step - loss: 0.3236 - binary_accuracy: 0.9102 - binary_crossentropy: 0.1942
# Epoch 84/100
# 28556/28556 [==============================] - 1s 40us/step - loss: 0.2856 - binary_accuracy: 0.9189 - binary_crossentropy: 0.1771
# Epoch 85/100
# 28556/28556 [==============================] - 1s 38us/step - loss: 0.3050 - binary_accuracy: 0.9134 - binary_crossentropy: 0.1865
# Epoch 86/100
# 28556/28556 [==============================] - 1s 36us/step - loss: 0.3467 - binary_accuracy: 0.9085 - binary_crossentropy: 0.2037
# Epoch 87/100
# 28556/28556 [==============================] - 1s 34us/step - loss: 0.2935 - binary_accuracy: 0.9142 - binary_crossentropy: 0.1788
# Epoch 88/100
# 28556/28556 [==============================] - 1s 34us/step - loss: 0.3127 - binary_accuracy: 0.9155 - binary_crossentropy: 0.1924
# Epoch 89/100
# 28556/28556 [==============================] - 1s 34us/step - loss: 0.3207 - binary_accuracy: 0.9112 - binary_crossentropy: 0.1954
# Epoch 90/100
# 28556/28556 [==============================] - 1s 34us/step - loss: 0.3133 - binary_accuracy: 0.9126 - binary_crossentropy: 0.1877
# Epoch 91/100
# 28556/28556 [==============================] - 1s 34us/step - loss: 0.2750 - binary_accuracy: 0.9198 - binary_crossentropy: 0.1694
# Epoch 92/100
# 28556/28556 [==============================] - 1s 34us/step - loss: 0.3103 - binary_accuracy: 0.9134 - binary_crossentropy: 0.1893
# Epoch 93/100
# 28556/28556 [==============================] - 1s 37us/step - loss: 0.2898 - binary_accuracy: 0.9154 - binary_crossentropy: 0.1815
# Epoch 94/100
# 28556/28556 [==============================] - 1s 38us/step - loss: 0.2971 - binary_accuracy: 0.9169 - binary_crossentropy: 0.1795
# Epoch 95/100
# 28556/28556 [==============================] - 1s 50us/step - loss: 0.2873 - binary_accuracy: 0.9191 - binary_crossentropy: 0.1818
# Epoch 96/100
# 28556/28556 [==============================] - 1s 40us/step - loss: 0.2892 - binary_accuracy: 0.9178 - binary_crossentropy: 0.1772
# Epoch 97/100
# 28556/28556 [==============================] - 1s 39us/step - loss: 0.2975 - binary_accuracy: 0.9184 - binary_crossentropy: 0.1786
# Epoch 98/100
# 28556/28556 [==============================] - 1s 43us/step - loss: 0.2961 - binary_accuracy: 0.9168 - binary_crossentropy: 0.1826
# Epoch 99/100
# 28556/28556 [==============================] - 1s 43us/step - loss: 0.2919 - binary_accuracy: 0.9180 - binary_crossentropy: 0.1802
# Epoch 100/100
# 28556/28556 [==============================] - 1s 43us/step - loss: 0.3129 - binary_accuracy: 0.9125 - binary_crossentropy: 0.1935

# %% [markdown]
# ### 7.4: Plot the model

# %%
test_points2 = tf.convert_to_tensor(np.random.uniform(np.nextafter(-1.0, 1.0), 1.0, (5000, 2)))
results2 = model2.predict(test_points2, steps = 1)
scatter = plt.scatter(test_points2[:, 0], test_points2[:, 1], results2) #darker points are more likely to be wall points (5000 points worked better than 100)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
